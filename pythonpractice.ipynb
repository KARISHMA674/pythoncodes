# %% [markdown]
# <a href="https://colab.research.google.com/github/KARISHMA674/pythoncodes/blob/main/pythonpractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **data type basic practice**

# %%
a=5
type(a)
id(a)
print(type(a))
print(id(a))
# Out:
# <class 'int'>
# 11645480

# %%
b=5.7
type(b)
id(b)
print(type(b))
print(id(b))
# Out:
# <class 'float'>
# 132136766403760

# %%
c=5+6j
type(c)
id(c)
print(type(c))
print(id(c))
# Out:
# <class 'complex'>
# 132136766403280

# %% [markdown]
# **function uses:-**

# %%
## error operation no perform only concatenation done.
e=input("enter a 1 no: ")
f=input("enter a 2 no: ")
g=(e)+(f)
print(g)
# Out:
# enter a 1 no: 2
# enter a 2 no: 4
# 24

# %%
e=input("enter a 1 no: ")
f=input("enter a 2 no: ")
g=( int(e)+(int)(f))
print(g)
# Out:
# enter a 1 no: 3
# enter a 2 no: 5
# 8

# %%
e=input("enter a 1 no: ")
f=input("enter a 2 no: ")
g=( int(e)+(float)(f))
print(g)
# Out:
# enter a 1 no: 3
# enter a 2 no: 2.4
# 5.4

# %%
e=input("enter a 1 no: ")
f=input("enter a 2 no: ")
g=( int(e)+(complex)(f))
print(g)
# Out:
# enter a 1 no: 3
# enter a 2 no: 2+6j
# (5+6j)

# %% [markdown]
# **userdefined practice**

# %%
def addsum():
  fnum=int(input("enter 1 no.: "))
  snum=int(input("enter 2 no.: "))
  sum = fnum+snum
  print("The sum of",fnum,"and",snum,"is",sum)
print(addsum())
# Out:
# enter 1 no.: 23
# enter 2 no.: 42
# The sum of 23 and 42 is 65
# None

# %%
def subnum():
  no1=int(input("no.1: "))
  no2=int(input("no.2: "))
  sub = no1-no2
  print("The subtraction of",no1,"and",no2,"is",sub)
print(subnum())
# Out:
# no.1: 5
# no.2: 3
# The subtraction of 5 and 3 is 2
# None

# %% [markdown]
# **basic loop**

# %%
def sum_square(n):
  sum=0
  for i in range(1,n+1):
      sum=sum+i
  print("The sum of first ",n,"natural numbers is:",sum)
num=int(input("enter the value for n: "))
sum_square(num)
# Out:
# enter the value for n: 5
# The sum of first  5 natural numbers is: 15

# %% [markdown]
# **factorial program by loop**

# %%
def calcfact(num):
  fact=1
  for i in range(num,0,-1):
    fact=fact*i
  print("factorial of",num,"is",fact)
num=int(input("enter the number: "))
print(calcfact(num))
# Out:
# enter the number: 5
# factorial of 5 is 120
# None

# %%
def fullname(first,last,work):
  fullname=first+" "+last+"\n"+work
  print("Hello !",fullname)
first=input("enter first name: ")
last=input("enter last name: ")
work=input("enter work: ")
fullname(first,last, work)
# Out:
# enter first name: karishma
# enter last name: singh
# enter work: pursuing btech
# Hello ! karishma singh
# pursuing btech

# %%
def studentinfo(name,enrollment_no,branchandsection,cgpa,joining_year,passing_year,institute_name):
  studentinfo_str = name + "\n" + str(enrollment_no) + "\n" +branchandsection + "\n" + str(cgpa) + "\n" + str(joining_year) + "\n" + str(passing_year) + "\n" + institute_name
  print("Hello! ",studentinfo_str)
name=input("Enter student name: ")
enrollment_no=int(input("Enter enrollment number of the student: "))
branchandsection=input("Enter branch and section of the student: ")
cgpa=float(input("Enter cgpa of the student: "))
joining_year=int(input("Enter the joining year of the student: "))
passing_year=int(input("Enter the passing year of the student: "))
institute_name=(input("Enter the institute name of the student: "))
studentinfo("The name of the student is " + name,
            "The enrollment no the student is " + str(enrollment_no),
            "The Branch and section of the student is " + branchandsection,
            "The cgpa of the student is "+ str(cgpa),
            "The joining year of the student is "+ str(joining_year),
            "The passing year of the student is "+str(passing_year),
            "The institute name in which the student is studing is " +institute_name)
# Out:
# Enter student name: Ranjit Gupta
# Enter enrollment number of the student: 11720802723
# Enter branch and section of the student: CSE-C
# Enter cgpa of the student: 8.7
# Enter the joining year of the student: 2023
# Enter the passing year of the student: 2027
# Enter the institute name of the student: Bhagwan Parshuram Institute Of  Technoloy Rohini sector-17
# Hello!  The name of the student is Ranjit Gupta
# The enrollment no the student is 11720802723
# The Branch and section of the student is CSE-C
# The cgpa of the student is 8.7
# The joining year of the student is 2023
# The passing year of the student is 2027
# The institute name in which the student is studing is Bhagwan Parshuram Institute Of  Technoloy Rohini sector-17
